# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file
import matplotlib.pyplot as plt # for data visualization purposes
import seaborn as sns # for statistical data visualization

# %%
import matplotlib.pyplot as plt

# Create a figure and plot some data
plt.plot([1, 2, 3, 4])
plt.xlabel('some data')
plt.ylabel('some numbers')

plt.show()

# %%
df = pd.read_csv("adult.csv")

# %%
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          10th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
df.shape  #this will give you shape of the dataset
# Out:
# (48842, 15)

# %%
df.head()  #this will give you first 5 rows of the dataset
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          10th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
df.tail()  #this will give you last 5 rows of the dataset
# Out:
#        age     workclass  fnlwgt   education  educational-num  \
# 48837   27       Private  257302  Assoc-acdm               12
# 48838   40       Private  154374     HS-grad                9
# 48839   58       Private  151910     HS-grad                9
# 48840   22       Private  201490     HS-grad                9
# 48841   52  Self-emp-inc  287927     HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 48837  Married-civ-spouse       Tech-support         Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 48839             Widowed       Adm-clerical    Unmarried  White  Female
# 48840       Never-married       Adm-clerical    Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 48837             0             0              38  United-States  <=50K
# ...

# %%
df.isnull().sum()  #this will give you sum of null values in each column
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
df.describe()  #this will give you statistical summary of the dataset
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48842.000000    48842.000000
# mean      87.502314       40.422382
# std      403.004552       12.391444
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
df.info()  #this will give you information about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
df.columns  #this will give you column names of the dataset
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
df.dtypes  #this will give you data types of the dataset
# Out:
# age                 int64
# workclass          object
# fnlwgt              int64
# education          object
# educational-num     int64
# marital-status     object
# occupation         object
# relationship       object
# race               object
# gender             object
# capital-gain        int64
# capital-loss        int64
# hours-per-week      int64
# native-country     object
# income             object
# dtype: object

# %%
df.nunique()  #this will give you number of unique values in each column
# Out:
# age                   74
# workclass              9
# fnlwgt             28523
# education             17
# educational-num       16
# marital-status         7
# occupation            15
# relationship           6
# race                   5
# gender                 2
# capital-gain         123
# capital-loss          99
# hours-per-week        96
# native-country        42
# income                 2
# dtype: int64

# %%
df.drop(["race","fnlwgt","relationship","capital-gain","capital-loss","workclass"], axis=1, inplace=True)
# this code will drop the column that are not useful in our dataset

# %%
df
# Out:
#        age     education  educational-num      marital-status  \
# 0       25          10th                7       Never-married
# 1       38       HS-grad                9  Married-civ-spouse
# 2       28    Assoc-acdm               12  Married-civ-spouse
# 3       44  Some-college               10  Married-civ-spouse
# 4       18  Some-college               10       Never-married
# ...    ...           ...              ...                 ...
# 48837   27    Assoc-acdm               12  Married-civ-spouse
# 48838   40       HS-grad                9  Married-civ-spouse
# 48839   58       HS-grad                9             Widowed
# 48840   22       HS-grad                9       Never-married
# 48841   52       HS-grad                9  Married-civ-spouse
#
#               occupation  gender  hours-per-week native-country income
# 0      Machine-op-inspct    Male              40  United-States  <=50K
# 1        Farming-fishing    Male              50  United-States  <=50K
# ...

# %%
# now we will convert categorial data(column) to numeric value
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

df["marital-status"] = le.fit_transform(df["marital-status"])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

df["education"] = le.fit_transform(df["education"])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

df["occupation"] = le.fit_transform(df["occupation"])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

df["gender"] = le.fit_transform(df["gender"])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

df["native-country"] = le.fit_transform(df["native-country"])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

df["income"] = le.fit_transform(df["income"])

# %%
df.isnull().sum()  #this will give you sum of null values in each column
# Out:
# age                0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# gender             0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
x= df.iloc[:,:-1].values
y= df.iloc[:,-1].values
# x is the independent variable and y is the dependent variable

# %% [markdown]
# ### Apply PCA

# %%
from sklearn.decomposition import PCA
pca = PCA(0.9)    #we can also use PCA(n_components = 2) : if we know that 2 component are contrubuting major portion of the dataset.
x_pca = pca.fit_transform(x)
x_pca
# Out:
# array([[-13.20089089,   3.52214582,  -1.73548788,  10.56629346],
#        [  2.31008654,   9.25167028,  -2.25727801,  -0.64040354],
#        [-10.20139818,   3.03247206,  -2.13446075,   2.33858298],
#        ...,
#        [ 18.14094073,  -6.55614887,  -2.35575121,  -1.37874959],
#        [-22.15041583, -14.53022825,  -2.32885275,  -1.62768813],
#        [ 12.57204707,  -4.57920704,  -2.32816035,  -0.98982595]])

# %%
pca.explained_variance_ratio_  # these are principle componenets
# Out:
# array([0.4292574 , 0.3352201 , 0.13530918, 0.04238341])

# %% [markdown]
# ### train_test_split splits a dataset into training and testing sets.
# ### It randomly assigns data points to each set, ensuring both sets are representative of the whole dataset.**bold text**

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size=0.5 , random_state = 42)

# %%
from sklearn.naive_bayes import GaussianNB
# Used for classification tasks,
# assumes features follow a Gaussian distribution

# %%
x[:10 , :20]
# Out:
# array([[25,  1,  7,  4,  7,  1, 40, 39],
#        [38, 12,  9,  2,  5,  1, 50, 39],
#        [28,  9, 12,  2, 11,  1, 40, 39],
#        [44, 16, 10,  2,  7,  1, 40, 39],
#        [18, 16, 10,  4,  0,  0, 30, 39],
#        [34,  8,  6,  4,  8,  1, 30, 39],
#        [29, 12,  9,  4,  0,  1, 40, 39],
#        [63, 15, 15,  2, 10,  1, 32, 39],
#        [24, 16, 10,  4,  8,  0, 40, 39],
#        [55,  6,  4,  2,  3,  1, 10, 39]])

# %%
'''
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

x_train= sc.fit_transform(x_train)
x_test= sc.transform(x_test)
x_train[:18,:10]
'''
# no need to standardize data
# no effect on naive bayes
# Out:
# '\nfrom sklearn.preprocessing import StandardScaler\nsc = StandardScaler()\n\nx_train= sc.fit_transform(x_train)\nx_test= sc.transform(x_test)\nx_train[:18,:10]\n'

# %%
model = GaussianNB()
model.fit(x_train, y_train)
'''
Creates a GaussianNB classifier instance.
Trains the model with provided training features (x_train) and labels (y_train).
The model learns the patterns and relationships between the features and labels.
'''
# Out:
# GaussianNB()

# %% [markdown]
# **Stores the predicted labels in the y_predict variable.**

# %%
y_predict = model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_predict)
print("Confusion matrix:     ",confusion_matrix)
# Confusion Matrix
# Out:
# Confusion matrix:      [[15872  2759]
#  [ 2006  3784]]

# %%
from sklearn.metrics import classification_report
classification_report = classification_report(y_test, y_predict)
print("Classification report:")
print(classification_report)
# Classification Report :
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.85      0.87     18631
#            1       0.58      0.65      0.61      5790
#
#     accuracy                           0.80     24421
#    macro avg       0.73      0.75      0.74     24421
# weighted avg       0.81      0.80      0.81     24421

# %% [markdown]
# ###The model achieved an overall accuracy of 80%.
#
# ###For class 0, the model has a precision of 89%, recall of 85%, and f1-score of 87%.
#
# ###For class 1, the model has a precision of 58%, recall of 65%, and f1-score of 61%.

# %%
# for accuracy
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_predict)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8048810450022521

# %%
# for r_square
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_predict)
print("R-squared:", r2)
# Out:
# R-squared: -0.07872717384039385

# %%
new_data = [[55,  5,  5,  13,  5,  1, 40, 40	]]
predicted_label = model.predict(new_data)
print("Predicted label for new data point:",y_predict[0])
# Out:
# Predicted label for new data point: 0

# %%
if predicted_label == 0:
    print("Prediction: <=50K")
else:
    print("Prediction: >50K")
# Out:
# Prediction: <=50K

# %% [markdown]
# ### ROC - AUC

# %%
# now we will make roc curve
from sklearn.metrics import roc_curve, roc_auc_score

# %%
# roc curve for our dataset
fpr, tpr, thresholds = roc_curve(y_test, y_predict)
roc_auc = roc_auc_score(y_test, y_predict)

# %%
#plot roc curve for our dataset
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %%
# area under curve
auc_score = auc(fpr, tpr)
print("Area under curve:", auc_score)
# Out:
# Area under curve: 0.7527270323783908
