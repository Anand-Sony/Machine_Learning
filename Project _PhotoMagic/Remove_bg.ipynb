# %%
pip install rembg

# %%
from rembg import remove

# %%
pip install PIL
# Out:
# ERROR: Could not find a version that satisfies the requirement PIL (from versions: none)
# ERROR: No matching distribution found for PIL

# %%
# !python -m PIL

# %%
pip install Pillow

# %%
import PIL

# %%
from PIL import Image

# %%
image_input = Image.open("Enter the path of the image : ")

# %%
image_input
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1166x1360>

# %%
output = remove(image_input)

# %%
output
# Out:
# <PIL.Image.Image image mode=RGBA size=1166x1360>
